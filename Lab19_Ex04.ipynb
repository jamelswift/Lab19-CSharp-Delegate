// %% [markdown]
// # Lab 19 Exercise 4

// %% [markdown]
// ## Passing delegate as parameter

// %% [markdown]
// 1.สร้าง console application project
//
// ```cmd
// dotnet new console --name Lab19_Ex04
// ```

// %% [markdown]
// 2.เปลี่ยน code ให้เป็นดังต่อไปนี้
//
// ```csharp
// // passing delegate as parameter
//
//
// var im = new InstanceMethod();
// MyDelegate imdel = im.MethodA;
// MyDelegate smdel = StaticMethod.MethodB;
// MyDelegate amdel = (string message) => System.Console.WriteLine($"You are calling anonymous method with message {message}");
// System.Console.WriteLine("------------------");
// System.Console.WriteLine("imdel + smdel");
// MyDelegate del = imdel + smdel  ;
// del("Hello world");
// System.Console.WriteLine("------------------");
// System.Console.WriteLine("imdel + smdel + amdel");
// del  += amdel  ;
// del("Hello world");
//
// System.Console.WriteLine("------------------");
// System.Console.WriteLine("del -= imdel ");
// del -= imdel;
// del("Hello world");
//
// class InstanceMethod
// {
//      public void MethodA(string message)
//      {
//         System.Console.WriteLine($"You are calling instance MethodA() with message {message}");
//      }
// }
// static class StaticMethod
// {
//      public static void MethodB(string message)
//      {
//         System.Console.WriteLine($"You are calling static MethodB() with message {message}");
//      }
// }
//
// public delegate void MyDelegate(string message);
// ```

// %% [markdown]
// 3.Build project โดยการใช้คำสั่ง
//
// ```cmd
// dotnet build  Lab19_Ex04
// ```
//
// ถ้ามีที่ผิดพลาดในโปรแกรม ให้แก้ไขให้ถูกต้อง

// %% [markdown]
// 4.บันทึกผลที่ได้จากการรันคำสั่งในข้อ 3

// %% [markdown]
// ![image.png](attachment:image.png)

// %% [markdown]
// 5.Run project โดยการใช้คำสั่ง
//
// ```cmd
// dotnet run --project Lab19_Ex04
// ```

// %% [markdown]
// 6.บันทึกผลที่ได้จากการรันคำสั่งในข้อ 5

// %% [markdown]
// ![image.png](attachment:image.png)

// %% [markdown]
// 7.อธิบายสิ่งที่พบในการทดลอง

// %% [markdown]
// สรุป
// - Multicast Delegate: เมื่อใช้ + หรือ += กับ delegate หลาย ๆ ตัว คุณสามารถสร้าง multicast delegate ซึ่งจะทำให้ delegate ชี้ไปยังเมธอดหลาย ๆ ตัวได้ และเมื่อเรียก delegate นี้จะทำให้ทุกเมธอดที่ผูกอยู่กับ delegate ถูกเรียก
// - การลบ Delegate: ใช้ -= เพื่อลบ delegate ที่ไม่ต้องการออกจากตัวแปร delegate
// - Delegate ช่วยให้โค้ดมีความยืดหยุ่นและสามารถรวมหลายเมธอดในการเรียกใช้งานครั้งเดียวได้ ซึ่งเหมาะกับการใช้งานที่ต้องการประมวลผลหลาย ๆ ฟังก์ชันพร้อมกันในลำดับที่กำหนด
